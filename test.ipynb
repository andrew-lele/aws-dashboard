# %%
import boto3

# %%
ec2 = boto3.client('ec2')
response = ec2.describe_instances()
print(response)
# Out:
# {'Reservations': [{'Instances': [{'BlockDeviceMappings': [{'Ebs': {'VolumeId': 'vol-9722418f', 'Status': 'attached', 'DeleteOnTermination': True, 'AttachTime': datetime.datetime(2014, 12, 4, 3, 31, 23, tzinfo=tzutc())}, 'DeviceName': '/dev/sda1'}], 'InstanceId': 'i-11dff4f0', 'PublicIpAddress': '54.88.75.175', 'PrivateDnsName': 'ip-10-10-0-166.ec2.internal', 'Monitoring': {'State': 'disabled'}, 'RootDeviceName': '/dev/sda1', 'SubnetId': 'subnet-be21da95', 'SecurityGroups': [{'GroupName': 'ImmuneProdNatAccessPeer', 'GroupId': 'sg-d9e70ebd'}], 'SourceDestCheck': False, 'RootDeviceType': 'ebs', 'State': {'Name': 'running', 'Code': 16}, 'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1}, 'StateTransitionReason': '', 'Hypervisor': 'xen', 'ClientToken': 'e6a9bbfc-3463-4f9d-ad86-70052bfe9335', 'ProductCodes': [], 'KeyName': 'ImmuneProdNatAccess', 'InstanceType': 'm1.small', 'LaunchTime': datetime.datetime(2018, 1, 27, 3, 39, 14, tzinfo=tzutc()), 'VpcId': 'vpc-00e17c65', 'Placement': {'GroupName': '', 'AvailabilityZone': 'us-east-1d', 'Tenancy': 'default'}, 'AmiLaunchIndex': 0, 'ImageId': 'ami-224dc94a', 'Tags': [{'Value': 'ImmuneProdNatAccessPeer', 'Key': 'Name'}], 'EbsOptimized': False, 'NetworkInterfaces': [{'Description': '', 'SourceDestCheck': False, 'VpcId': 'vpc-00e17c65', 'Ipv6Addresses': [], 'Groups': [{'GroupName': 'ImmuneProdNatAccessPeer', 'GroupId': 'sg-d9e70ebd'}], 'SubnetId': 'subnet-be21da95', 'Attachment': {'AttachmentId': 'eni-attach-2765135a', 'DeviceIndex': 0, 'Status': 'attached', 'DeleteOnTermination': True, 'AttachTime': datetime.datetime(2014, 12, 4, 3, 31, 20, tzinfo=tzutc())}, 'Association': {'PublicDnsName': 'ec2-54-88-75-175.compute-1.amazonaws.com', 'PublicIp': '54.88.75.175', 'IpOwnerId': '092698858857'}, 'OwnerId': '092698858857', 'Status': 'in-use', 'PrivateIpAddresses': [{'Association': {'PublicDnsName': 'ec2-54-88-75-175.compute-1.amazonaws.com', 'PublicIp': '54.88.75.175', 'IpOwnerId': '092698858857'}, 'PrivateIpAddress': '10.10.0.166', 'PrivateDnsName': 'ip-10-10-0-166.ec2.internal', 'Primary': True}], 'PrivateDnsName': 'ip-10-10-0-166.ec2.internal', 'MacAddress': '12:90:b0:51:65:cd', 'NetworkInterfaceId': 'eni-aa82ad80', 'PrivateIpAddress': '10.10.0.166'}], 'KernelId': 'aki-919dcaf8', 'PublicDnsName': 'ec2-54-88-75-175.compute-1.amazonaws.com', 'Architecture': 'x86_64', 'VirtualizationType': 'paravirtual', 'PrivateIpAddress': '10.10.0.166'}], 'OwnerId': '092698858857', 'ReservationId': 'r-9dca6e73', 'Groups': []}, {'Instances': [{'BlockDeviceMappings': [{'Ebs': {'VolumeId': 'vol-c1ee4d8e', 'Status': 'attached', 'DeleteOnTermination': True, 'AttachTime': datetime.datetime(2014, 9, 9, 4, 33, 20, tzinfo=tzutc())}, 'DeviceName': '/dev/sda1'}], 'InstanceId': 'i-97967e79', 'PublicIpAddress': '50.16.89.82', 'PrivateDnsName': 'ip-10-0-0-226.ec2.internal', 'Monitoring': {'State': 'disabled'}, 'RootDeviceName': '/dev/sda1', 'SubnetId': 'subnet-cd7a6ee5', 'SecurityGroups': [{'GroupName': 'default', 'GroupId': 'sg-e86e3d8d'}], 'SourceDestCheck': False, 'RootDeviceType': 'ebs', 'State': {'Name': 'running', 'Code': 272}, 'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1}, 'StateTransitionReason': '', 'Hypervisor': 'xen', 'ClientToken': 'qpgGw1410237195871', 'ProductCodes': [], 'KeyName': 'ImmuneTestNatAccess', 'InstanceType': 'm1.small', 'LaunchTime': datetime.datetime(2018, 1, 20, 3, 25, 42, tzinfo=tzutc()), 'VpcId': 'vpc-5fb8123a', 'Placement': {'GroupName': '', 'AvailabilityZone': 'us-east-1d', 'Tenancy': 'default'}, 'AmiLaunchIndex': 0, 'ImageId': 'ami-4f9fee26', 'Tags': [{'Value': 'ImmuneTestNatAccess', 'Key': 'Name'}], 'EbsOptimized': False, 'NetworkInterfaces': [{'Description': 'Primary network interface', 'SourceDestCheck': False, 'VpcId': 'vpc-5fb8123a', 'Ipv6Addresses': [], 'Groups': [{'GroupName': 'default', 'GroupId': 'sg-e86e3d8d'}], 'SubnetId': 'subnet-cd7a6ee5', 'Attachment': {'AttachmentId': 'eni-attach-f613088c', 'DeviceIndex': 0, 'Status': 'attached', 'DeleteOnTermination': True, 'AttachTime' ...

# %%
ec2 = boto3.client('ec2')

# Retrieves all regions/endpoints that work with EC2
response = ec2.describe_regions()
print('Regions:', response['Regions'])

# Retrieves availability zones only for region of the ec2 object
response = ec2.describe_availability_zones()
print('Availability Zones:', response['AvailabilityZones'])
# Out:
# Regions: [{'RegionName': 'ap-south-1', 'Endpoint': 'ec2.ap-south-1.amazonaws.com'}, {'RegionName': 'eu-west-3', 'Endpoint': 'ec2.eu-west-3.amazonaws.com'}, {'RegionName': 'eu-west-2', 'Endpoint': 'ec2.eu-west-2.amazonaws.com'}, {'RegionName': 'eu-west-1', 'Endpoint': 'ec2.eu-west-1.amazonaws.com'}, {'RegionName': 'ap-northeast-2', 'Endpoint': 'ec2.ap-northeast-2.amazonaws.com'}, {'RegionName': 'ap-northeast-1', 'Endpoint': 'ec2.ap-northeast-1.amazonaws.com'}, {'RegionName': 'sa-east-1', 'Endpoint': 'ec2.sa-east-1.amazonaws.com'}, {'RegionName': 'ca-central-1', 'Endpoint': 'ec2.ca-central-1.amazonaws.com'}, {'RegionName': 'ap-southeast-1', 'Endpoint': 'ec2.ap-southeast-1.amazonaws.com'}, {'RegionName': 'ap-southeast-2', 'Endpoint': 'ec2.ap-southeast-2.amazonaws.com'}, {'RegionName': 'eu-central-1', 'Endpoint': 'ec2.eu-central-1.amazonaws.com'}, {'RegionName': 'us-east-1', 'Endpoint': 'ec2.us-east-1.amazonaws.com'}, {'RegionName': 'us-east-2', 'Endpoint': 'ec2.us-east-2.amazonaws.com'}, {'RegionName': 'us-west-1', 'Endpoint': 'ec2.us-west-1.amazonaws.com'}, {'RegionName': 'us-west-2', 'Endpoint': 'ec2.us-west-2.amazonaws.com'}]
# Availability Zones: [{'ZoneName': 'us-east-1a', 'Messages': [], 'RegionName': 'us-east-1', 'State': 'available'}, {'ZoneName': 'us-east-1b', 'Messages': [], 'RegionName': 'us-east-1', 'State': 'available'}, {'ZoneName': 'us-east-1c', 'Messages': [], 'RegionName': 'us-east-1', 'State': 'available'}, {'ZoneName': 'us-east-1d', 'Messages': [], 'RegionName': 'us-east-1', 'State': 'available'}, {'ZoneName': 'us-east-1e', 'Messages': [], 'RegionName': 'us-east-1', 'State': 'available'}, {'ZoneName': 'us-east-1f', 'Messages': [], 'RegionName': 'us-east-1', 'State': 'available'}]
